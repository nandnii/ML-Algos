# %% [markdown]
# # EVALUATING MODEL PERFORMANCE

# %% [markdown]
# ![Screenshot%20%2815%29.png](attachment:Screenshot%20%2815%29.png)

# %% [markdown]
# ### Closer R^2 is to 1, better the better the model is!

# %% [markdown]
# # REGRESSION PROS & CONS

# %% [markdown]
# ![Regression-Pros&Cons.PNG](attachment:Regression-Pros&Cons.PNG)

# %% [markdown]
# # 1. False Positive & Negative

# %% [markdown]
# ![Screenshot%20%2824%29.png](attachment:Screenshot%20%2824%29.png)

# %% [markdown]
# * **False Positive** - When you predict something will happen but it doesn't happen.
# * **False Negative** - When you predict something won't happen but it actually happens.

# %% [markdown]
# # 2. Confusion Matrix

# %% [markdown]
# ![Screenshot%20%2828%29.png](attachment:Screenshot%20%2828%29.png)

# %% [markdown]
# # 3. Accuracy Rate

# %% [markdown]
# ![Screenshot%20%2830%29.png](attachment:Screenshot%20%2830%29.png)

# %% [markdown]
# This is our **Accuracy Rate** when we're using the model, & now we stop using our model that is, every prediction we make is 0, so this will happen 👇🏻

# %% [markdown]
# ![Screenshot%20%2831%29.png](attachment:Screenshot%20%2831%29.png)

# %% [markdown]
# Accuracy Rate increased even though we stopped using our model, so this can be very misleading. Therefore, it's not recommended & this phenomenan is called as **Accuracy Paradox.**

# %% [markdown]
# # 4. Cumulative Accuracy Profile (CAP) Curve

# %% [markdown]
# ![Screenshot%20%2832%29.png](attachment:Screenshot%20%2832%29.png)
